# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import datetime as dt

# %%
csv1 = pd.read_csv("D:\Work Datasets\Cleaned Datasets\cleaned_data_1.csv")
csv3 = pd.read_csv("D:\Work Datasets\Cleaned Datasets\cleaned_data_3.csv")
csv4 = pd.read_csv("D:\Work Datasets\Cleaned Datasets\cleaned_data_4.csv")

# %%
# MERGING 'csv3' & 'csv4' USING INNER JOIN
df = pd.merge(csv3,csv4,on=['customer_id'])

# MERGING ABOVE DATAFRAME AND 'csv1' USING LEFT JOIN
df1_3_4 = pd.merge(csv1,df,how = 'left',on=['customer_id'])

# %%
df1_3_4.to_csv("D:\Work Datasets\merged_data.csv",index= False)

# %%
dataset = df1_3_4.sort_values(by = ['customer_id'])

# %%
dataset.shape
# Out:
# (19821, 29)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19821 entries, 15518 to 17310
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   transaction_id                       19821 non-null  int64
#  1   product_id                           19821 non-null  int64
#  2   customer_id                          19821 non-null  int64
#  3   transaction_date                     19821 non-null  object
#  4   online_order                         19821 non-null  float64
#  5   order_status                         19821 non-null  object
#  6   brand                                19821 non-null  object
#  7   product_line                         19821 non-null  object
#  8   product_class                        19821 non-null  object
#  9   product_size                         19821 non-null  object
#  10  list_price                           19821 non-null  float64
#  11  standard_cost                        19645 non-null  float64
#  12  product_first_sold_date              19821 non-null  object
#  13  first_name                           19782 non-null  object
#  14  last_name                            19782 non-null  object
#  15  gender                               19782 non-null  object
#  16  past_3_years_bike_related_purchases  19782 non-null  float64
#  17  DOB                                  19782 non-null  object
#  18  job_title                            19782 non-null  object
#  19  job_industry_category                19782 non-null  object
#  20  wealth_segment                       19782 non-null  object
#  21  deceased_indicator                   19782 non-null  object
#  22  owns_car                             19782 non-null  object
#  23  tenure                               19782 non-null  float64
#  24  address                              19782 non-null  object
#  25  postcode                             19782 non-null  float64
#  26  state                                19782 non-null  object
#  27  country                              19782 non-null  object
#  28  property_valuation                   19782 non-null  float64
# dtypes: float64(7), int64(3), object(19)
# memory usage: 4.5+ MB

# %%
dataset.isnull().sum()
# Out:
# transaction_id                           0
# product_id                               0
# customer_id                              0
# transaction_date                         0
# online_order                             0
# order_status                             0
# brand                                    0
# product_line                             0
# product_class                            0
# product_size                             0
# list_price                               0
# standard_cost                          176
# product_first_sold_date                  0
# first_name                              39
# last_name                               39
# gender                                  39
# past_3_years_bike_related_purchases     39
# DOB                                     39
# job_title                               39
# job_industry_category                   39
# wealth_segment                          39
# deceased_indicator                      39
# owns_car                                39
# tenure                                  39
# address                                 39
# postcode                                39
# state                                   39
# country                                 39
# property_valuation                      39
# dtype: int64

# %%
#mean of standard_cost column
dataset['standard_cost'].mean()
# Out:
# 555.8288289655434

# %%
#median of standard_cost column
dataset['standard_cost'].median()
# Out:
# 507.58

# %%
# FILLING THE NULL VALUES IN 'standard_cost' USING THE FILLNA METHOD AND THE ITS MEAN
dataset['standard_cost'] = dataset['standard_cost'].fillna(dataset['standard_cost'].mean())

# %%
# SETTING A CONDITION FOR DROPPING ROWS WITH NO FIRST NAMES AND LAST NAMES
dropthresh = dataset[(dataset['first_name'].isnull()) & (dataset['last_name'].isnull())].index
dataset.drop(dropthresh,inplace = True)

# %%
dataset.isnull().sum()
# Out:
# transaction_id                         0
# product_id                             0
# customer_id                            0
# transaction_date                       0
# online_order                           0
# order_status                           0
# brand                                  0
# product_line                           0
# product_class                          0
# product_size                           0
# list_price                             0
# standard_cost                          0
# product_first_sold_date                0
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# dtype: int64

# %% [markdown]
# # So, now the dataset is cleaned...

# %% [markdown]
# # Now , we need to create certain columns so that the picking out of our top 1000 customers becomes easier...

# %%
dataset['profit'] = dataset['list_price'] - dataset['standard_cost']

# %%
dataset.head()
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 15518           15663          32            1       2017-06-04           1.0
# 13293           13424           2            1       2017-02-21           0.0
# 16276           16423           9            1       2017-12-09           1.0
# 18796           18970          11            1       2017-03-29           1.0
# 14786           14931          31            1       2017-12-14           1.0
#
#       order_status           brand product_line product_class product_size  \
# 15518     Approved  Giant Bicycles     Standard        medium       medium
# 13293     Approved           Solex     Standard        medium       medium
# 16276     Approved      OHM Cycles         Road        medium       medium
# 18796     Approved  Giant Bicycles     Standard          high       medium
# 14786     Approved  Giant Bicycles     Standard        medium       medium
#
#        ...  wealth_segment  deceased_indicator owns_car tenure  \
# 15518  ...   Mass Customer               False     True   11.0
# 13293  ...   Mass Customer               False     True   11.0
# 16276  ...   Mass Customer               False     True   11.0
# 18796  ...   Mass Customer               False     True   11.0
# 14786  ...   Mass Customer               False     True   11.0
#
#                   address postcode            state    country  \
# 15518  060 Morning Avenue   2016.0  New South Wales  Australia
# 13293  060 Morning Avenue   2016.0  New South Wales  Australia
# 16276  060 Morning Avenue   2016.0  New South Wales  Australia
# 18796  060 Morning Avenue   2016.0  New South Wales  Australia
# 14786  060 Morning Avenue   2016.0  New South Wales  Australia
#
#       property_valuation  profit
# 15518               10.0  431.33
# 13293               10.0   17.87
# 16276               10.0   75.14
# 18796               10.0  509.97
# 14786               10.0   57.73
#
# [5 rows x 30 columns]

# %%
dataset.tail()
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 19658           19836          40         3500       2017-03-14           1.0
# 8327             8416          74         3500       2017-02-16           0.0
# 8471             8562          33         3500       2017-08-08           0.0
# 14727           14870          22         3500       2017-01-11           0.0
# 6241             6309          69         3500       2017-01-09           1.0
#
#       order_status           brand product_line product_class product_size  \
# 19658     Approved      OHM Cycles     Standard          high       medium
# 8327      Approved        WeareA2B     Standard        medium       medium
# 8471      Approved  Giant Bicycles     Standard        medium        small
# 14727     Approved        WeareA2B     Standard        medium       medium
# 6241      Approved  Giant Bicycles         Road        medium       medium
#
#        ...     wealth_segment  deceased_indicator owns_car tenure  \
# 19658  ...  Affluent Customer               False    False   17.0
# 8327   ...  Affluent Customer               False    False   17.0
# 8471   ...  Affluent Customer               False    False   17.0
# 14727  ...  Affluent Customer               False    False   17.0
# 6241   ...  Affluent Customer               False    False   17.0
#
#                         address postcode            state    country  \
# 19658  9491 Green Ridge Terrace   2100.0  New South Wales  Australia
# 8327   9491 Green Ridge Terrace   2100.0  New South Wales  Australia
# 8471   9491 Green Ridge Terrace   2100.0  New South Wales  Australia
# 14727  9491 Green Ridge Terrace   2100.0  New South Wales  Australia
# 6241   9491 Green Ridge Terrace   2100.0  New South Wales  Australia
#
#       property_valuation  profit
# 19658               10.0  583.27
# 8327                10.0  827.16
# 8471                10.0  144.26
# 14727               10.0   15.08
# 6241                10.0  198.22
#
# [5 rows x 30 columns]

# %%
dataset.to_csv("D:\Work Datasets\merged_data.csv",index = False)

# %% [markdown]
# # Insights from the merged data...

# %%
import seaborn as sns 

# population count based on gender 
sns.countplot(x = 'gender', data = dataset)
plt.title('Gender count barchart')
plt.show()

# %%
plt.figure(figsize = (16,8))
sns.countplot(x='job_industry_category', data = dataset)
plt.title('Job industry category barchart')
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.countplot(x = 'wealth_segment', data = dataset)
plt.title('Wealth segment distribution')
plt.xlabel('Wealth segment')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.countplot(x='gender', data=dataset, hue='wealth_segment')
plt.legend(title='Wealth Segment', loc='upper right', fancybox=True)
plt.title('Wealth Segment across gender')
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.countplot(x='state', data=dataset, hue='wealth_segment')
plt.legend(title='Wealth segment', loc='upper right', fancybox=True)
plt.title('Wealth Segment across state')
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.countplot(x = 'state', data = dataset, hue = 'owns_car')
plt.legend(title='State', loc='upper right', fancybox=True)
plt.title('Number of people owning car in different state')
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.catplot(data=dataset, x='gender', y='profit')
plt.title('Profits earned across gender')
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.barplot(data=dataset, x='gender', y='profit')
plt.title('Profits earned across gender')
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.barplot(data=dataset, x='brand', y='profit')
plt.title('Profits earned across brand')
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.barplot(data=dataset, x='product_line', y='profit')
plt.title('Profits earned across Product Line')
plt.show()

# %%
plt.figure(figsize = (18,9))
sns.barplot(data=dataset, x='job_industry_category', y='profit')
plt.title('Profits earned across Job Industry')
plt.show()

# %%
plt.figure(figsize = (18,9))
sns.barplot(data=dataset, x='wealth_segment', y='profit')
plt.title('Profits earned across Wealth Segment')
plt.show()

# %%
plt.figure(figsize = (18,9))
sns.lineplot(data=dataset, x='wealth_segment', y='profit')
plt.title('Profits earned across Wealth Segment')
plt.show()
